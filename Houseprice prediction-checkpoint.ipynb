# %%
import pandas as pd

# %%
train=pd.read_csv("Housepricetrain.csv")

# %%
test=pd.read_csv("Housepricetest.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#DistPlot of the target variable
sns.distplot(train.SalePrice)

# %%
sns.heatmap(train.corr())

# %%
#identification of features with greater correlation
train.corr().nlargest(10,"SalePrice")["SalePrice"]
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64

# %%
features=["OverallQual","GrLivArea","GarageCars","GarageArea","TotalBsmtSF","1stFlrSF","FullBath","TotRmsAbvGrd","YearBuilt","SalePrice"]

# %%
sns.heatmap(train[features].corr(),annot=True)

# %%
sns.pairplot(train[features])

# %%
features_=["OverallQual","GrLivArea","GarageCars","GarageArea","TotalBsmtSF","1stFlrSF","FullBath","TotRmsAbvGrd","YearBuilt"]

# %%
#Identification of null values in the dataset
train[features_].isnull().sum()
# Out:
# OverallQual     0
# GrLivArea       0
# GarageCars      0
# GarageArea      0
# TotalBsmtSF     0
# 1stFlrSF        0
# FullBath        0
# TotRmsAbvGrd    0
# YearBuilt       0
# dtype: int64

# %%
test[features_].isnull().sum()
# Out:
# OverallQual     0
# GrLivArea       0
# GarageCars      1
# GarageArea      1
# TotalBsmtSF     1
# 1stFlrSF        0
# FullBath        0
# TotRmsAbvGrd    0
# YearBuilt       0
# dtype: int64

# %%
test.fillna(test.mean(),inplace=True)

# %%
test[features_].isnull().sum()
# Out:
# OverallQual     0
# GrLivArea       0
# GarageCars      0
# GarageArea      0
# TotalBsmtSF     0
# 1stFlrSF        0
# FullBath        0
# TotRmsAbvGrd    0
# YearBuilt       0
# dtype: int64

# %%
#Model preparation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

# %%
Y=train["SalePrice"].values
X=train[features_].values
test=test[features_].values

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
#Linear regression model
ll=LinearRegression()
ll.fit(X_train,Y_train)
Y_pred_test=ll.predict(X_test)
Y_pred_train=ll.predict(X_train)

# %%
#model evaluation
mse_test=mean_squared_error(Y_test,Y_pred_test)
mse_train=mean_squared_error(Y_train,Y_pred_train)
r2_test=r2_score(Y_test,Y_pred_test)
r2_train=r2_score(Y_train,Y_pred_train)
print("Test set:"+ "  MSE="+str(mse_test)+ "  R2="+str(r2_test))
print("Train set:"+ "  MSE="+str(mse_train)+ "  R2="+str(r2_train))
# Out:
# Test set:  MSE=1317858646.8470821  R2=0.758163855110327
# Train set:  MSE=1509760446.552269  R2=0.7735038208953848

# %%
plt.plot(Y_test,label="Test set")
plt.plot(Y_pred_test,label="Predictions")

# %%
from sklearn.linear_model import Ridge,Lasso,ElasticNet

# %%
#Regularization L2
alphas=[0.0001,0.001,0.01,0.1,1,10]
for i in alphas:
    model=Ridge(alpha=i)
    model.fit(X_train,Y_train)
    Y_pred_test=model.predict(X_test)
    Y_pred_train=model.predict(X_train)
    mse_test=mean_squared_error(Y_test,Y_pred_test) 
    mse_train=mean_squared_error(Y_train,Y_pred_train)
    r2_test=r2_score(Y_test,Y_pred_test)
    r2_train=r2_score(Y_train,Y_pred_train)
    print("ALPHA"+ str(i))
    print("Test set:"+ "  MSE="+str(mse_test)+"  R2="+str(r2_test))
    print("Train set:"+ "  MSE="+str(mse_train)+"  R2="+str(r2_train))
# Out:
# ALPHA0.0001
# Test set:  MSE=1317858645.029434  R2=0.758163855443878
# Train set:  MSE=1509760446.5522847  R2=0.7735038208953825
# ALPHA0.001
# Test set:  MSE=1317858628.671842  R2=0.7581638584456089
# Train set:  MSE=1509760446.5538611  R2=0.773503820895146
# ALPHA0.01
# Test set:  MSE=1317858465.2232668  R2=0.758163888439549
# Train set:  MSE=1509760446.711429  R2=0.7735038208715075
# ALPHA0.1
# Test set:  MSE=1317856843.455291  R2=0.7581641860451505
# Train set:  MSE=1509760462.449862  R2=0.7735038185104077
# ALPHA1
# Test set:  MSE=1317841881.166548  R2=0.7581669317282607
# Train set:  MSE=1509762018.1342092  R2=0.7735035851246668
# ALPHA10
# Test set:  MSE=1317803356.3884602  R2=0.7581740012905676
# Train set:  MSE=1509901528.926536  R2=0.7734826555384678

# %%
#Regularization l2
alphas=[0.0001,0.001,0.01,0.1,1,10]
for i in alphas:
    model=Lasso(alpha=i)
    model.fit(X_train,Y_train)
    Y_pred_test=model.predict(X_test)
    Y_pred_train=model.predict(X_train)
    mse_test=mean_squared_error(Y_test,Y_pred_test) 
    mse_train=mean_squared_error(Y_train,Y_pred_train)
    r2_test=r2_score(Y_test,Y_pred_test)
    r2_train=r2_score(Y_train,Y_pred_train)
    print("ALPHA"+ str(i))
    print("Test set:"+ "  MSE="+str(mse_test)+"  R2="+str(r2_test))
    print("Train set:"+ "  MSE="+str(mse_train)+"  R2="+str(r2_train))
# Out:
# ALPHA0.0001
# Test set:  MSE=1317858648.0313156  R2=0.7581638548930121
# Train set:  MSE=1509760446.5522697  R2=0.7735038208953847
# ALPHA0.001
# Test set:  MSE=1317858658.6895156  R2=0.7581638529371589
# Train set:  MSE=1509760446.552289  R2=0.7735038208953818
# ALPHA0.01
# Test set:  MSE=1317858765.2726555  R2=0.7581638333784181
# Train set:  MSE=1509760446.5542624  R2=0.7735038208950858
# ALPHA0.1
# Test set:  MSE=1317859831.2630014  R2=0.7581636377618424
# Train set:  MSE=1509760446.7515767  R2=0.7735038208654845
# ALPHA1
# Test set:  MSE=1317870507.3560867  R2=0.7581616786251775
# Train set:  MSE=1509760466.483082  R2=0.773503817905339
# ALPHA10
# Test set:  MSE=1317978890.5787935  R2=0.7581417895567916
# Train set:  MSE=1509762439.600271  R2=0.7735035218957931

# %%
#Regularization l2 and l1
alphas=[0.0001,0.001,0.01,0.1,1,10]
for i in alphas:
    model=ElasticNet(alpha=i,l1_ratio=0.5)
    model.fit(X_train,Y_train)
    Y_pred_test=model.predict(X_test)
    Y_pred_train=model.predict(X_train)
    mse_test=mean_squared_error(Y_test,Y_pred_test) 
    mse_train=mean_squared_error(Y_train,Y_pred_train)
    r2_test=r2_score(Y_test,Y_pred_test)
    r2_train=r2_score(Y_train,Y_pred_train)
    print("ALPHA"+ str(i))
    print("Test set:"+ "  MSE="+str(mse_test)+"  R2="+str(r2_test))
    print("Train set:"+ "  MSE="+str(mse_train)+"  R2="+str(r2_train))
# Out:
# ALPHA0.0001
# Test set:  MSE=1317857722.3415952  R2=0.758164024763456
# Train set:  MSE=1509760450.706818  R2=0.7735038202721141
# ALPHA0.001
# Test set:  MSE=1317849735.3058279  R2=0.7581654904395689
# Train set:  MSE=1509760859.564143  R2=0.7735037589348192
# ALPHA0.01
# Test set:  MSE=1317800819.178299  R2=0.7581744668861194
# Train set:  MSE=1509799457.2408216  R2=0.7734979684623571
# ALPHA0.1
# Test set:  MSE=1319199673.914184  R2=0.7579177674006349
# Train set:  MSE=1512297631.0409508  R2=0.7731231892569801
# ALPHA1
# Test set:  MSE=1367520117.3972652  R2=0.7490506329782406
# Train set:  MSE=1572858268.082571  R2=0.7640378055953585
# ALPHA10
# Test set:  MSE=1556581718.9553552  R2=0.7143565260064015
# Train set:  MSE=1792425748.832735  R2=0.7310980133527509

# %%
#Random forest regressor model
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor(n_estimators=30)
rfr.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=30, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rfr_test=rfr.predict(X_test)
rfr_train=rfr.predict(X_train)

# %%
#Model evaluation
mse_test=mean_squared_error(Y_test,rfr_test)
r2_test=r2_score(Y_test,rfr_test)
mse_train=mean_squared_error(Y_train,rfr_train)
r2_train=r2_score(Y_train,rfr_train)
print("Test set"+"  MSE="+str(mse_test)+"  R2="+str(r2_test))
print("Train set:"+ "  MSE="+str(mse_train)+"  R2="+str(r2_train))
# Out:
# Test set  MSE=1303333676.0493476  R2=0.760829287363447
# Train set:  MSE=210702468.82188544  R2=0.9683901481026023

# %%
plt.plot(Y_test)
plt.plot(rfr_test)

# %%
#Gradient boosting regressor model
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor(n_estimators=300)
gbr.fit(X_train,Y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=300,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
gbr_test=gbr.predict(X_test)
gbr_train=gbr.predict(X_train)

# %%
#Model avaluation
mse_test=mean_squared_error(Y_test,gbr_test)
mse_train=mean_squared_error(Y_train,gbr_train)
r2_test=r2_score(Y_test,gbr_test)
r2_train=r2_score(Y_train,gbr_train)
print("Test set:"+ "  MSE="+str(mse_test)+ "  R2="+str(r2_test))
print("Train set:"+ "  MSE="+str(mse_train)+ "  R2="+str(r2_train))
# Out:
# Test set:  MSE=1221323975.6441712  R2=0.7758786326304786
# Train set:  MSE=183094016.92000756  R2=0.9725320031108248

# %%
plt.plot(Y_test)
plt.plot(gbr_test)

# %%
#Model validation
from sklearn.model_selection import cross_val_score

# %%
#Linear regression model validation
scores=cross_val_score(ll,X_train,Y_train,cv=10)
scores.mean()
# Out:
# 0.7376521531109903

# %%
#Random forest regressor model validation
scores=cross_val_score(rfr,X_train,Y_train,cv=10)
scores.mean()
# Out:
# 0.8305511424133991

# %%
#Gradient boosting regresso model validation
scores=cross_val_score(gbr,X_train,Y_train,cv=10)
scores.mean()
# Out:
# 0.8073398408069625

# %%
#Preparing test data and predictions
submission_sample=pd.read_csv("sample_submissionhouse.csv")

# %%
predictions=rfr.predict(test)

# %%
output=pd.DataFrame({"Id":submission_sample.Id,"SalePrice":predictions})

# %%
output
# Out:
#         Id      SalePrice
# 0     1461  121458.333333
# 1     1462  153851.666667
# 2     1463  168109.333333
# 3     1464  184056.666667
# 4     1465  216321.666667
# ...    ...            ...
# 1454  2915   81316.666667
# 1455  2916   77433.333333
# 1456  2917  150301.966667
# 1457  2918  119240.000000
# 1458  2919  239083.366667
#
# [1459 rows x 2 columns]
